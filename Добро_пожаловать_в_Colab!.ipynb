# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    np.arange(24).reshape(6, 4),
    columns=["A", "B", "C", "D"]
)

print(df)
# Out:
#     A   B   C   D
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
# 4  16  17  18  19
# 5  20  21  22  23

# %%
print(df["A"])
# Out:
# 0     0
# 1     4
# 2     8
# 3    12
# 4    16
# 5    20
# Name: A, dtype: int64

# %%
print(df[["A", "C"]])
# Out:
#     A   C
# 0   0   2
# 1   4   6
# 2   8  10
# 3  12  14
# 4  16  18
# 5  20  22

# %%
print(df.iloc[2:5])
# Out:
#     A   B   C   D
# 2   8   9  10  11
# 3  12  13  14  15
# 4  16  17  18  19

# %%
print(df.loc[1:3, ["A", "C"]])
# Out:
#     A   C
# 1   4   6
# 2   8  10
# 3  12  14

# %%
filtered = df[df["A"] > 10]

print(filtered)
print("Count:", filtered.shape[0])
# Out:
#     A   B   C   D
# 3  12  13  14  15
# 4  16  17  18  19
# 5  20  21  22  23
# Count: 3

# %%
result = df[(df["A"] > 5) & (df["B"] < 20)]
print(result)
res=[(df["A"] > 5) | (df["B"] < 20)]
print(res)
# Out:
#     A   B   C   D
# 2   8   9  10  11
# 3  12  13  14  15
# 4  16  17  18  19
# [0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# dtype: bool]

# %%
result_query = df.query("A > 5 and B < 20")
print(result_query)
# Out:
#     A   B   C   D
# 2   8   9  10  11
# 3  12  13  14  15
# 4  16  17  18  19

# %%
print(df)
# Out:
#     A   B   C   D
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
# 4  16  17  18  19
# 5  20  21  22  23

# %%
df.loc[df["A"] > 10, "B"] = 999
print(df)
# Out:
#     A    B   C   D
# 0   0    1   2   3
# 1   4    5   6   7
# 2   8    9  10  11
# 3  12  999  14  15
# 4  16  999  18  19
# 5  20  999  22  23

# %%
df[df["A"] > 10]["B"] = 0
# Out:
# /tmp/ipykernel_1719/3252851636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df["A"] > 10]["B"] = 0

# %%
df.loc[df["A"] > 10, "B"] = 0
print(df)
# Out:
#     A  B   C   D
# 0   0  1   2   3
# 1   4  5   6   7
# 2   8  9  10  11
# 3  12  0  14  15
# 4  16  0  18  19
# 5  20  0  22  23
